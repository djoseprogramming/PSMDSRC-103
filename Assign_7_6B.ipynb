# %% [markdown]
# <a href="https://colab.research.google.com/github/djoseprogramming/PSMDSRC-103/blob/main/Assign_7_6B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Preparation

# %%
import datetime
import csv
import pandas as pd
# NumPy is a library that adds support for large, multi-dimensional arrays and matrices
# along with high-level mathematical functions to operate on these arrays
import numpy as np
from matplotlib import pylab as plt
# %matplotlib inline

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
#set the location of the data file
filepath = '/content/drive/MyDrive/PSMDS_RC103_Programming/Activities/07/data/rpi_data_test.csv'

# %%
data_file = '/content/drive/MyDrive/PSMDS_RC103_Programming/Activities/07/data/rpi_data_test.csv'

# %%
# !head -n 5 '/content/drive/MyDrive/PSMDS_RC103_Programming/Activities/07/data/rpi_data_test.csv'
# Out:
# Ping:,21.117,ms,Download:,78.19,Mbit/s,Upload:,116.83,Mbit/s,26/04/2025 20:24
# Ping:,28.315,ms,Download:,82.64,Mbit/s,Upload:,117.64,Mbit/s,26/04/2025 20:25
# Ping:,19.427,ms,Download:,78.11,Mbit/s,Upload:,117.03,Mbit/s,26/04/2025 20:25
# Ping:,21.908,ms,Download:,81.82,Mbit/s,Upload:,115.98,Mbit/s,26/04/2025 20:25
# Ping:,33.998,ms,Download:,67.25,Mbit/s,Upload:,102.75,Mbit/s,26/04/2025 20:26

# %%
column_names = [ 'Type A', 'Measure A', 'Units A',
                 'Type B', 'Measure B', 'Units B',
                 'Type C', 'Measure C', 'Units C',
                 'Datetime']

# %%
with open(data_file, 'r') as f:
    df_redundant = pd.read_csv(f, names = column_names)

# %%
df_redundant.head()
# Out:
#   Type A  Measure A Units A     Type B  Measure B Units B   Type C  Measure C  \
# 0  Ping:     21.117      ms  Download:      78.19  Mbit/s  Upload:     116.83
# 1  Ping:     28.315      ms  Download:      82.64  Mbit/s  Upload:     117.64
# 2  Ping:     19.427      ms  Download:      78.11  Mbit/s  Upload:     117.03
# 3  Ping:     21.908      ms  Download:      81.82  Mbit/s  Upload:     115.98
# 4  Ping:     33.998      ms  Download:      67.25  Mbit/s  Upload:     102.75
#
#   Units C          Datetime
# 0  Mbit/s  26/04/2025 20:24
# 1  Mbit/s  26/04/2025 20:25
# 2  Mbit/s  26/04/2025 20:25
# 3  Mbit/s  26/04/2025 20:25
# 4  Mbit/s  26/04/2025 20:26

# %%
# Copy df_redundant into another dataframe called df_compact using copy()
df_compact = df_redundant.copy()

# %%
df_compact.rename(columns={'Measure A':'Ping (ms)',
                           'Measure B': 'Download (Mbit/s)',
                           'Measure C': 'Upload (Mbit/s)'}, inplace=True)

# %%
df_compact.head(3)
# Out:
#   Type A  Ping (ms) Units A     Type B  Download (Mbit/s) Units B   Type C  \
# 0  Ping:     21.117      ms  Download:              78.19  Mbit/s  Upload:
# 1  Ping:     28.315      ms  Download:              82.64  Mbit/s  Upload:
# 2  Ping:     19.427      ms  Download:              78.11  Mbit/s  Upload:
#
#    Upload (Mbit/s) Units C          Datetime
# 0           116.83  Mbit/s  26/04/2025 20:24
# 1           117.64  Mbit/s  26/04/2025 20:25
# 2           117.03  Mbit/s  26/04/2025 20:25

# %%
df_compact.drop(['Type A', 'Type B', 'Type C',
        'Units A', 'Units B', 'Units C'], axis=1, inplace=True)
df_compact.head()
# Out:
#    Ping (ms)  Download (Mbit/s)  Upload (Mbit/s)          Datetime
# 0     21.117              78.19           116.83  26/04/2025 20:24
# 1     28.315              82.64           117.64  26/04/2025 20:25
# 2     19.427              78.11           117.03  26/04/2025 20:25
# 3     21.908              81.82           115.98  26/04/2025 20:25
# 4     33.998              67.25           102.75  26/04/2025 20:26

# %%
### Separate data into two columns
df_compact['Date'] = df_compact['Datetime'].apply(lambda dt_str: pd.to_datetime(dt_str).date())
temp = df_compact['Datetime'].apply(lambda dt_str: pd.to_datetime(dt_str))
df_compact['Time'] = pd.to_datetime(df_compact['Datetime']).dt.time
df_compact.drop('Datetime', axis=1, inplace=True)
# Out:
# <ipython-input-13-2bea99e3a0a7>:2: UserWarning: Parsing dates in %d/%m/%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_compact['Date'] = df_compact['Datetime'].apply(lambda dt_str: pd.to_datetime(dt_str).date())
# <ipython-input-13-2bea99e3a0a7>:3: UserWarning: Parsing dates in %d/%m/%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   temp = df_compact['Datetime'].apply(lambda dt_str: pd.to_datetime(dt_str))
# <ipython-input-13-2bea99e3a0a7>:4: UserWarning: Parsing dates in %d/%m/%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_compact['Time'] = pd.to_datetime(df_compact['Datetime']).dt.time

# %%
df_compact.head(3)
# Out:
#    Ping (ms)  Download (Mbit/s)  Upload (Mbit/s)        Date      Time
# 0     21.117              78.19           116.83  2025-04-26  20:24:00
# 1     28.315              82.64           117.64  2025-04-26  20:25:00
# 2     19.427              78.11           117.03  2025-04-26  20:25:00

# %%
df_compact.dtypes
# Out:
# Ping (ms)            float64
# Download (Mbit/s)    float64
# Upload (Mbit/s)      float64
# Date                  object
# Time                  object
# dtype: object

# %%
# Find and remove any null values
df_compact.isnull().sum().sum()

# Remove NaN values
df_compact = df_compact.dropna()

# %%
# Convert Ping and Download to float
df_compact['Ping (ms)'] = df_compact['Ping (ms)'].apply(lambda val: float(val))
df_compact['Download (Mbit/s)'] = df_compact['Download (Mbit/s)'].apply(lambda val: float(val))

# %%
df_compact.to_csv('rpi_data_processed.csv', index=False)
df_compact.dtypes
# Out:
# Ping (ms)            float64
# Download (Mbit/s)    float64
# Upload (Mbit/s)      float64
# Date                  object
# Time                  object
# dtype: object

# %%
data_file = 'rpi_data_processed.csv'

# %%
df_compact = pd.read_csv(data_file)

# %%
df_compact
# Out:
#    Ping (ms)  Download (Mbit/s)  Upload (Mbit/s)        Date      Time
# 0     21.117              78.19           116.83  2025-04-26  20:24:00
# 1     28.315              82.64           117.64  2025-04-26  20:25:00
# 2     19.427              78.11           117.03  2025-04-26  20:25:00
# 3     21.908              81.82           115.98  2025-04-26  20:25:00
# 4     33.998              67.25           102.75  2025-04-26  20:26:00
